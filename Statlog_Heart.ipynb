# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report,
)


from qiskit.circuit.library import ZZFeatureMap, PauliFeatureMap
from qiskit_machine_learning.algorithms.classifiers import VQC
from qiskit_algorithms.utils import algorithm_globals
from qiskit_algorithms.optimizers import COBYLA
from qiskit.primitives import Sampler

from ucimlrepo import fetch_ucirepo

from ansatz import ansatz_kazuma, ansatz_aqua

# %% [markdown]
# ### EDA (Exploratory Data Analysis)

# %% [markdown]
# #### Fetching Dataset

# %%
# Fetching the first dataset
statlog_heart = fetch_ucirepo(id=145)

df = pd.DataFrame(statlog_heart.data.features)
df["target"] = pd.DataFrame(statlog_heart.data.targets)

# %% [markdown]
# #### Removing Outliers

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# age                     13.0
# sex                      1.0
# chest-pain               1.0
# rest-bp                 20.0
# serum-chol              67.0
# fasting-blood-sugar      0.0
# electrocardiographic     2.0
# max-heart-rate          33.0
# angina                   1.0
# oldpeak                  1.6
# slope                    1.0
# major-vessels            1.0
# thal                     4.0
# target                   1.0
# dtype: float64
# (192, 14)

# %%
features = df.drop(columns=['target'])  # Drop the target column to create the feature set
target = df['target']

# %%
print("Features shape:", features.shape)  # Should match target's shape
print("Target shape:", target.shape)

# Check for missing values
print(features.isnull().sum())
print(target.isnull().sum())

# Reset index if necessary
features.reset_index(drop=True, inplace=True)
target.reset_index(drop=True, inplace=True)
# Out:
# Features shape: (192, 13)
# Target shape: (192,)
# age                     0
# sex                     0
# chest-pain              0
# rest-bp                 0
# serum-chol              0
# fasting-blood-sugar     0
# electrocardiographic    0
# max-heart-rate          0
# angina                  0
# oldpeak                 0
# slope                   0
# major-vessels           0
# thal                    0
# dtype: int64
# 0

# %% [markdown]
# ### Classical Approach

# %%
# Scaling between 0 and 1

features = PCA(n_components=8).fit_transform(features)
features = MinMaxScaler().fit_transform(features)

# %%
algorithm_globals.random_seed = 3459
train_features, test_features, train_labels, test_labels = train_test_split(
    features, target, train_size=0.7, random_state=algorithm_globals.random_seed
)

svc = SVC()
_ = svc.fit(train_features, train_labels)  # suppress printing the return value
classical_train_score = svc.score(train_features, train_labels)
classical_test_score = svc.score(test_features, test_labels)

print(f"Classical SVC on the training dataset: {classical_train_score:.2f}")
print(f"Classical SVC on the test dataset:     {classical_test_score:.2f}")
# Out:
# Classical SVC on the training dataset: 0.91
# Classical SVC on the test dataset:     0.81

# %%
objective_func_vals = []
plt.rcParams["figure.figsize"] = (12, 6)

def callback_graph(weights, obj_func_eval):
    clear_output(wait=True)
    objective_func_vals.append(obj_func_eval)
    plt.title("Objective function value against iteration")
    plt.xlabel("Iteration")
    plt.ylabel("Objective function value")
    plt.plot(range(len(objective_func_vals)), objective_func_vals)
    plt.show()

# %%
train_labels = np.array(train_labels.to_list())

# %%
# Numbers of qubits
num_features = features.shape[1]

vqc_zz_1 = VQC(
    sampler=Sampler(),
    feature_map=ZZFeatureMap(feature_dimension=num_features, reps=2),
    ansatz= ansatz_aqua(num_qubits=num_features, reps=3),
    optimizer=COBYLA(maxiter=50),
    callback=callback_graph,
)

# clear objective value history
objective_func_vals = []

start = time.time()
vqc_zz_1.fit(train_features, train_labels)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")
quantum_train_score = vqc_zz_1.score(train_features, train_labels)
quantum_test_score = vqc_zz_1.score(test_features, test_labels)

print(f"Quantum VQC on the training dataset: {quantum_train_score:.2f}")
print(f"Quantum VQC on the test dataset:     {quantum_test_score:.2f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 16
#      13 objective_func_vals = []
#      15 start = time.time()
# ---> 16 vqc_zz_1.fit(train_features, train_labels)
#      17 elapsed = time.time() - start
#      19 print(f"Training time: {round(elapsed)} seconds")
#
# File d:\FAST\QC\Quantum-Computing\.venv\Lib\site-packages\qiskit_machine_learning\algorithms\trainable_model.py:199, in TrainableModel.fit(self, X, y)
#     196 if not self._warm_start:
#     197     self._fit_result = None
# --> 199 self._fit_result = self._fit_internal(X, y)
#     200 return self
#
# File d:\FAST\QC\Quantum-Computing\.venv\Lib\site-packages\qiskit_machine_learning\algorithms\classifiers\vqc.py:167, in VQC._fit_internal(self, X, y)
#     164     self._neural_network.set_interpret(self._get_interpret(num_classes), num_classes)
# ...

# %%
# Numbers of qubits
num_features = features.shape[1]

vqc_p_1 = VQC(
    sampler=Sampler(),
    feature_map=PauliFeatureMap(
        feature_dimension=num_features, reps=2, paulis=["Z", "YY"], entanglement="full"
    ),
    ansatz=ansatz_aqua(num_qubits=num_features, reps=2),
    optimizer=COBYLA(maxiter=100),
    callback=callback_graph,
)

# clear objective value history
objective_func_vals = []

start = time.time()
vqc_p_1.fit(train_features, train_labels)
elapsed = time.time() - start

print(f"Training time: {round(elapsed)} seconds")
quantum_train_score = vqc_p_1.score(train_features, train_labels)
quantum_test_score = vqc_p_1.score(test_features, test_labels)

print(f"Quantum VQC on the training dataset: {quantum_train_score:.2f}")
print(f"Quantum VQC on the test dataset:     {quantum_test_score:.2f}")
# Out:
# Training time: 302 seconds
# Quantum VQC on the training dataset: 0.63
# Quantum VQC on the test dataset:     0.52

# %%
dataset_name = "Statlog Heart"

classical_predictions = svc.predict(test_features)
qc_1 = vqc_zz_1.predict(test_features)
qc_2 = vqc_p_1.predict(test_features)

print(f"""Dataset Name:\t{dataset_name}
                        Accuracy\tPrecision\tRecall\t\tF1 Score
Classical               {accuracy_score(test_labels, classical_predictions):.2f}\t\t{precision_score(test_labels, classical_predictions):.2f}\t\t{recall_score(test_labels, classical_predictions):.2f}\t\t{f1_score(test_labels, classical_predictions):.2f} 
QC (ZZ Feature Map)     {accuracy_score(test_labels, qc_1):.2f}\t\t{precision_score(test_labels, qc_1):.2f}\t\t{recall_score(test_labels, qc_1):.2f}\t\t{f1_score(test_labels, qc_1):.2f} 
QC (Pauli Feature Map)  {accuracy_score(test_labels, qc_2):.2f}\t\t{precision_score(test_labels, qc_2):.2f}\t\t{recall_score(test_labels, qc_2):.2f}\t\t{f1_score(test_labels, qc_2):.2f} 
    """)
# Out:
# Dataset Name:	Statlog Heart
#                         Accuracy	Precision	Recall		F1 Score
# Classical               0.81		0.87		0.79		0.83
# QC (ZZ Feature Map)     0.53		0.61		0.59		0.60
# QC (Pauli Feature Map)  0.52		0.59		0.56		0.58
